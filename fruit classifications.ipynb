# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, r2_score

# %%
df = pd.read_csv("C:/Users/rtani/Desktop/Coading/apple classification/archive/apple_quality.csv")
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
df.drop('A_id', axis=1, inplace=True)

# %%
df
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# ...

# %%
df['Acidity'].unique()
# Out:
# array(['-0.491590483', '-0.722809367', '2.621636473', ..., '-2.229719806',
#        '1.599796456', 'Created_by_Nidula_Elgiriyewithana'], dtype=object)

# %%
df = df[df['Acidity'] != 'Created_by_Nidula_Elgiriyewithana']

# %%
df['Acidity'] = df['Acidity'].astype(float)
# Out:
# C:\Users\rtani\AppData\Local\Temp\ipykernel_17532\643451254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Acidity'] = df['Acidity'].astype(float)

# %%
df['Quality'].value_counts()
# Out:
# good    2004
# bad     1996
# Name: Quality, dtype: int64

# %%
le = LabelEncoder()
df['Quality'] = le.fit_transform(df['Quality'])
# Out:
# C:\Users\rtani\AppData\Local\Temp\ipykernel_17532\764530054.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quality'] = le.fit_transform(df['Quality'])

# %%
df.head()
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness   Acidity  \
# 0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840 -0.491590
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530 -0.722809
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033  2.621636
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761  0.790723
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849  0.501984
#
#    Quality
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1

# %%
X = df.drop('Quality', axis=1)
y = df['Quality']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)
pred = knn.predict(X)
score = accuracy_score(y,pred)
score
# Out:
# 0.9665

# %%
r2 = r2_score(y,pred)
r2
# Out:
# 0.865999463997856

# %%
df['predict'] = pred
# Out:
# C:\Users\rtani\AppData\Local\Temp\ipykernel_17532\3831272094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predict'] = pred

# %%
print(df['Quality'].value_counts())
print(df['predict'].value_counts())
# Out:
# 1    2004
# 0    1996
# Name: Quality, dtype: int64
# 1    2008
# 0    1992
# Name: predict, dtype: int64

# %%
df['Quality'] = df['Quality'].replace({1:'good', 0:'bad'})
df['predict'] = df['predict'].replace({1:'good', 0:'bad'})
# Out:
# C:\Users\rtani\AppData\Local\Temp\ipykernel_17532\2799448598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quality'] = df['Quality'].replace({1:'good', 0:'bad'})
# C:\Users\rtani\AppData\Local\Temp\ipykernel_17532\2799448598.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predict'] = df['predict'].replace({1:'good', 0:'bad'})

# %%
df.head(10)
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness   Acidity  \
# 0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840 -0.491590
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530 -0.722809
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033  2.621636
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761  0.790723
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849  0.501984
# 5 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616 -2.981523
# 6  1.331606  1.635956   0.875974    -1.677798   3.106344 -1.847417  2.414171
# 7 -1.995462 -0.428958   1.530644    -0.742972   0.158834  0.974438 -1.470125
# 8 -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921 -4.871905
# 9 -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857  2.185608
#
#   Quality predict
# 0    good    good
# 1    good    good
# 2     bad     bad
# 3    good    good
# 4    good    good
# ...
